# %%
import pandas as pd

# %%
cambio = pd.read_csv('cambio.csv')

# %%
cambio.head(6)
# Out:
#          Data  \
# 0  02/01/2001
# 1  03/01/2001
# 2  04/01/2001
# 3  05/01/2001
# 4  06/01/2001
# 5  07/01/2001
#
#    Taxa de câmbio - R$ / US$ - comercial - futuro: vencimento em t+1 - R$ - Bolsa de Valores- Mercadorias e Futuros (BM&FBovespa) - BMF366_FUT1DOL366  \
# 0                                           1.959736
# 1                                           1.965246
# 2                                           1.957205
# 3                                           1.972200
# 4                                                NaN
# 5                                                NaN
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN

# %%
cambio.tail()
# Out:
#             Data  \
# 9277  28/05/2026
# 9278  29/05/2026
# 9279  30/05/2026
# 9280  31/05/2026
# 9281  01/06/2026
#
#       Taxa de câmbio - R$ / US$ - comercial - futuro: vencimento em t+1 - R$ - Bolsa de Valores- Mercadorias e Futuros (BM&FBovespa) - BMF366_FUT1DOL366  \
# 9277                                            5.04944
# 9278                                            5.07550
# 9279                                                NaN
# 9280                                                NaN
# 9281                                            5.04438
#
#       Unnamed: 2
# 9277         NaN
# 9278         NaN
# 9279         NaN
# 9280         NaN
# 9281         NaN
