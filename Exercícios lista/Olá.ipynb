# %%
""" Este programa pergunta o nome do usuário e apresenta a mensagem "oi..." com o nome inserido. """
# Out:
# ' Este programa pergunta o nome do usuário e apresenta a mensagem "oi..." com o nome inserido. '

# %%
#Memória e Entrada de dados
nome = ""
nome = input(str('Qual o seu nome? '))
# Out:
# Qual o seu nome?  Nicole
# Oi {(nome)}

# %%
#Processamento
print('Oi,', nome)
# Out:
# Oi, Nicole
