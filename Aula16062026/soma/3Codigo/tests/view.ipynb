# %%
def impressora():
    """ Esta função imprime na tela """
    pass

# %%
def impressora(dados: list, resultado: float) -> None:
    """ Esta função imprime na tela """
    print(f'A soma dos números {dados[0]} e {dados[1]} é igual a {resultado}.')

# %%
dados = [1,2]
resultado = 3
impressora(dados, resultado)
# Out:
# A soma dos números 1 e 2 é igual a 3.
