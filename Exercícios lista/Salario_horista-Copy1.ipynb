# %% [markdown]
# # Este programa calcula o salário de um trabalhador horista. Ele pergunta o número de horas trabalhadas, o valor da hora, calcula e imprimir na tela o valor do salário bruto, líquido e o total de descontos, conforme progressão IR
# ## Versão 0.0.2
# ## 18/06/2026
# ## Nicole S. D Giustina
#
#
# #Memória
# n_horas = 0
# v_hora = 0.0
# salario_bruto = 0.0
# salario_liq = 0.0
# irpf = 0.0

# %%
#Entrada
n_horas = int(input(f'\nQuantas horas você trabalhou esse mês? '))
v_hora = float(input(f'\nQual o valor contratual da sua hora de trabalho? '))
# Out:
# Quantas horas você trabalhou esse mês?  250
#
# Qual o valor contratual da sua hora de trabalho?  128.60

# %%
#Processamento
def salario_bruto ():
    return n_horas * v_hora

# %%
salario_bruto()
# Out:
# 32150.0

# %%
def irpf ():
    if salario_bruto() < 5000:
        irpf = 0
    elif salario_bruto() > 7350:
        irpf = salario_bruto() * 0.275 - 908.73 
    else:
        irpf = salario_bruto() * 0.275 - 908.73 - (978.62 - (0.133145 * salario_bruto()))
    return irpf

# %%
irpf()
# Out:
# 7932.52

# %%
def salario_liq ():
    return salario_bruto() - irpf()

# %%
salario_liq()
# Out:
# 24217.48
